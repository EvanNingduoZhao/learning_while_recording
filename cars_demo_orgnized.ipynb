# %%
import pandas as pd
import pip
#! pip install apyori
from apyori import apriori
pd.options.display.max_columns = 40
pd.options.display.max_rows = 1000

# %% [markdown]
# # Data Manipulation

# %%
# Read in the data and fixing the encoding problems
df_with34_55 = pd.read_csv('10000rows.csv',encoding = 'GB2312')
# drop the first columns which is useless
df_with34_55.drop(df_with34_55.columns[0],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-234-8dfec09ae6d6> in <module>
#       1 # Read in the data and fixing the encoding problems
# ----> 2 df_with34_55 = pd.read_csv('10000rows.csv',encoding = 'GB2312')
#       3 # drop the first columns which is useless
#       4 df_with34_55.drop(df_with34_55.columns[0],axis=1,inplace=True)
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'10000rows.csv' does not exist: b'10000rows.csv'

# %%
# dropping all unused columns
df_with34_55.drop(columns=['IF_CAR_NETWORK',
                 'CNT_TEL',
                  'Role',
                 'dt_Cadillac_CLUB',
                 'Cadillac_point_accu',
                'IF_Buick_CLUB_FLAG',
                'level_Buick',
                'dt_Buick_CLUB',
                'Buick_point_accu',
                'IF_chevy_CLUB_FLAG',
                'level_chevy',
                'dt_chevy_CLUB',
                'chevy_point_accu',
                'CNT_YB_FEE',
                'service_purchase',
                          'IF_CLUB_CAR',
                          'IF_Cadillac_CLUB_FLAG',
                          'contact_CNT_TEL',
                          'DELIVERER_CNT_TEL',
                          'member_CNT_TEL'],axis=1,inplace=True)
df=df_with34_55.drop(columns=['LASTY_CNT_CGBY',
                          'LASTY_AMT_CGBY',
                         'LASTY_CNT_CLDX',
                         'LASTY_AMT_CLDX',
                         'LASTY_CNT_ZBSP',
                         'LASTY_AMT_ZBSP',
                         'LASTY_CNT_NO_ZBSP',
                         'LASTY_AMT_NO_ZBSP',
                         'LASTY_CNT_CGBY_BN',
                         'LASTY_AMT_CGBY_BN',
                         'LASTY_CNT_PTWX_BN',
                         'LASTY_AMT_PTWX_BN',
                             'LASTY_CNT_PTWX_BY',
                             'LASTY_AMT_PTWX_BY',
                             'LASTY_CNT_SGWX',
                             'LASTY_AMT_SGWX',
                             'LASTY_CNT_BUY_YHCP',
                             'LASTY_CNT_WXZ'],axis=1)

# %%
# only include cadillac vehicles
cadillac = df[df['HOLD_GRAND']=='凯迪拉克']
cadillac.drop(cadillac.columns[0],axis=1,inplace=True)
# only include individual costumers, exclude all organizational buyers
cadillac = cadillac[cadillac['IF_ORG_CUST']==0]
# drop Car_model since cadillac only has one model in this dataset
cadillac.drop(columns=['Car_model'],inplace=True)
#rename the cols with mis-spells
new_cols = cadillac.columns.values
new_cols[0]="first_buy_mon"

# %%
# make sure 一人一车
cust_ID_count={}
for index,row in cadillac.iterrows():
    if row['CUST_ID'] in cust_ID_count:
        cust_ID_count[row['CUST_ID']]+=1
    else:
        cust_ID_count[row['CUST_ID']]=1

more_than_1_list=[]
for key,value in cust_ID_count.items():
    if value>1:
        more_than_1_list.append(key)

for id in  more_than_1_list:
    cadillac=cadillac[cadillac['CUST_ID'] != id]

# %%
# make sure all age>0, all first buy month are not null
cadillac=cadillac.loc[cadillac['Age']>0]
cadillac['first_buy_mon']=cadillac['first_buy_mon'].fillna(-1)
cadillac=cadillac.loc[cadillac['first_buy_mon']>0]

# %%
# only include vehicles' MSRP with [50000,600000] (reasonable range)
cadillac['LAST_AMT_MSRP']=cadillac['LAST_AMT_MSRP'].fillna(50001)
cadillac=cadillac[(cadillac['LAST_AMT_MSRP']>50000)]
cadillac=cadillac[(cadillac['LAST_AMT_MSRP']<600000)]
# null MSRP are marked as -1
cadillac.loc[cadillac['LAST_AMT_MSRP']==50001,'LAST_AMT_MSRP']=-1

# %%
# handling null values

cadillac['Gender']=cadillac['Gender'].fillna('Unknown')
cadillac['Age']=cadillac['Age'].fillna(-1)
cadillac['Province']=cadillac['Province'].fillna('Unknown')
# -1 already exist in city as 5 tier city, -2 represents null
cadillac['City']=cadillac['City'].fillna(-2)
cadillac['level_Cadillac']=cadillac['level_Cadillac'].fillna('非会员')
cadillac['LASTY_MILEAGE']=cadillac['LASTY_MILEAGE'].fillna(-1)
cadillac['LASTY_AMT_BUY_YHCP']=cadillac['LASTY_AMT_BUY_YHCP'].fillna(0)
cadillac['LASTY_AMT_JS']=cadillac['LASTY_AMT_JS'].fillna(0)
cadillac['LASTY_CNT_ACTIVE_CGBY']=cadillac['LASTY_CNT_ACTIVE_CGBY'].fillna(-100)
cadillac['first_buy_mon']=cadillac['first_buy_mon'].fillna(-1)
cadillac['LASTY_CNT_JZ']=cadillac['LASTY_CNT_JZ'].fillna(-1)

# %%
# group packaged into 3 categories
cadillac['package_grouped']='Unknown'
cadillac.loc[cadillac['package'].str.contains('技术'),'package_grouped']='低配'
cadillac.loc[cadillac['package'].str.contains('领先'),'package_grouped']='高配'
cadillac.loc[cadillac['package'].str.contains('豪华'),'package_grouped']='高配'
cadillac.loc[cadillac['package'].str.contains('时尚'),'package_grouped']='普配'
cadillac.loc[cadillac['package'].str.contains('精英'),'package_grouped']='普配'
cadillac.loc[cadillac['package'].str.contains('舒适'),'package_grouped']='普配'

# %%
# Add a column to display post_sale_Y
cadillac['post_sale_y']=cadillac['LASTY_AMT_BUY_YHCP']+cadillac['LASTY_AMT_JS']

# %%
cadillac['LASTY_CNT_JZ'].describe()
# Out:
# count    713.000000
# mean       1.809257
# std        1.969593
# min       -1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       10.000000
# Name: LASTY_CNT_JZ, dtype: float64

# %% [markdown]
# # Prepare ready to be passed to Aporiori API data

# %%
# first step construct a list of dictionaries, each dictionary represent a row

# vin number skipped, MSRP waited till packages,if_org is already filtered,HOLD_GRAND all the same
# plan to store used one among the 12 services as a list, with key '12_services' 
# if_type_car all the same, insaic_money not mentioned in meeting,province and 
cadillac_dicts = []
for index,row in cadillac.iterrows():
    row_dict = {}
    
    # Temporarily set the post_sale_y threshold as 7000
    if row['post_sale_y']>7000:
        row_dict['post_sale_y']='High Customer Value'
    else:
        row_dict['post_sale_y']='Low Customer Value'
    
    # vehicles bought less than 18 months are considered new since first maintenance should be prior to that
    if row['first_buy_mon']>0 and row['first_buy_mon']<=12:
        row_dict['first_buy_mon']="1 year vehicle"
    # between a year and a half and 4 years is consider middle age 
    elif row['first_buy_mon']>12 and row['first_buy_mon']<=24:
        row_dict['first_buy_mon']="2 year vehicle"
        
    elif row['first_buy_mon']>24 and row['first_buy_mon']<=36:
        row_dict['first_buy_mon']="3 year vehicle"
    elif row['first_buy_mon']>36 and row['first_buy_mon']<=48:
        row_dict['first_buy_mon']="4 year vehicle"
    elif row['first_buy_mon']>48 and row['first_buy_mon']<=60:
        row_dict['first_buy_mon']="5 year vehicle"
    # more than 4 years is considered old since the max in this dataset is 58 and 75% percentile is 37
    elif row['first_buy_mon']>60:
        row_dict['first_buy_mon']="5 older vehicle"
    else:
        row_dict['first_buy_mon']='Unknown'
     
    
    
    # divide to 13 categories(13 keys), one is AJX not installed, the other 12 are 12 AJX serveices
    # if any one of these 13 applies to a vehicle, then it's dict contain the corresponding key value pair
    # where value is the chinses name of the key
    
    # 12 services can all coexist with the others, AJX not installed can only coexist with CKJCBG（车况检测报告）
    # since a few IF_AJX_cust==0 rows has IF_CKJCBG = 1
    services_12 = ['IF_CMYCYJKQ', 'IF_MDDSZXZ', 'IF_CTWZTS',
       'IF_JJJYXZ', 'IF_SSAXJC', 'IF_BDCLDW', 'IF_QCYKLH', 'IF_QYKMTDH',
       'IF_LBJYXZ', 'IF_AQQNBKZZQZ', 'IF_CKJCBG', 'IF_PZZDQZ']
    used=False
    for service in services_12:
        if row[service]==1:
            used=True
    if used == False:
        row_dict['IF_AJX_cust']='AJX not installed'
    
#     if row['IF_AJX_cust']==0:
#         if row['IF_CKJCBG']==0:
#             row_dict['IF_AJX_cust']='AJX not installed'
#         else:
#             row_dict['IF_AJX_cust']='AJX not installed but 车况检测报告'
    
    
    
    
    # handling gender, applied ffill to gender
    if row['Gender']=='男':
        row_dict['Gender'] = 'Male'
    elif row['Gender']=='女':
        row_dict['Gender'] = 'Female'
    else:
        row_dict['Gender'] = 'Unknown'
        
    
    #handling age, applied ffill to age
    # only less than 20% are older than 40
    if row['Age']<=24 and row['Age']>0:
        row_dict['Age'] = 'School Age'
    elif row['Age']>24 and row['Age']<30:
         row_dict['Age'] = 'Age 20s'
    elif row['Age']>=30 and row['Age']<40:
         row_dict['Age'] = 'Age 30s'
    elif row['Age']>=40:
         row_dict['Age'] = 'Age 40s Older'
    else:
         row_dict['Age'] = 'Unknown'
    
    
    #how to group provinces yet to be discussed, ask Daniel iff combine provinces
    d1=['浙江','上海','福建']
    d2=['江苏','安徽']
    d3=['广东','湖南','广西','江西','海南']
    d4=['四川','湖北','云南','贵州','重庆','新疆','甘肃','青海']
    d5=['山东','陕西','辽宁','吉林','黑龙江','内蒙古','山西','宁夏']
    d6=['北京','河南','河北','天津']
    if row['Province'] in d1:
        row_dict['Sales_district']='Sales_district1浙沪闽'
    elif row['Province'] in d2:
        row_dict['Sales_district']='Sales_district2江苏安徽'
    elif row['Province'] in d3:
        row_dict['Sales_district']='Sales_district3粤湘桂赣琼'
    elif row['Province'] in d4:
        row_dict['Sales_district']='Sales_district4云贵川鄂渝疆甘青'
    elif row['Province'] in d5:
        row_dict['Sales_district']='Sales_district5鲁陕辽吉黑蒙晋宁'
    elif row['Province'] in d6:
        row_dict['Sales_district']='Sales_district6河南河北京津'
    else:
         row_dict['Sales_district']='Unknown'
    
    
    # applied ffill to cities
    if row['City'] == 1:
        row_dict['City']= "1 Tier City"
    elif row['City']==2:
        row_dict['City'] = '2 Tier City'
    elif row['City']==3:
        row_dict['City'] = '3 Tier City'
    elif row['City']==4:
        row_dict['City'] = '4 Tier City'
    elif row['City']==0-1:
        row_dict['City'] = '5 Tier City'
    else:
        row_dict['City']='Unknown'
     
    
    # marriage -1 means other or unkown marital status, 1 means married, 2 means unmarried
    # more than 75% are unknown marital stuatus
    if row['Marriage']==1:
        row_dict['Marriage']= 'Married'
    elif row['Marriage']==2:
        row_dict['Marriage']= 'Unmarried'
    else:
        row_dict['Marriage']= 'Unknown'
      
    
    # null in level cadillac means not a member, already replaced null values with '非会员'
    if row['level_Cadillac']== '普卡':
        row_dict['level_Cadillac']='普卡'
    elif row['level_Cadillac']== '银卡':
        row_dict['level_Cadillac']='银卡'
    elif row['level_Cadillac']== '金卡':
        row_dict['level_Cadillac']='金卡'
    elif row['level_Cadillac']== '白金卡':
        row_dict['level_Cadillac']='白金卡'
    else:
        row_dict['level_Cadillac']='非会员'
    
    
    #insaic_cust 1 means client bought insaic insurance, 0 means bought from other sources
    if row['insaic_cust'] == 1:
        row_dict['insaic_cust']='Bought insaic'
    else:
        row_dict['insaic_cust']= 'Didnot buy insaic'
        
        
    # Warranty 0 means did not extend warranty, 1 means did extend warranty
    if row['Warranty']==1:
        row_dict['Warranty']='Extended Warranty'
    else:
        row_dict['Warranty']='Unextended Warranty'
    
    
    # IF_CAR_LOAN 1 means loaned from GM, 0 mean didnot loan from GM but not sure if loaned from others
    if row['IF_CAR_LOAN']==1:
        row_dict['IF_CAR_LOAN']='Loaned'
    else:
        row_dict['IF_CAR_LOAN']='Unloaned'
        
        
    
    #LASTY_MILEAGE
    # replaced null values with -1
    #count      636.000000
    #mean     16331.234543
    #std       9957.809315
    #min       1708.400613
    #25%       9696.742687
    #50%      14198.489512
    #75%      20111.688624
    #max      65905.044118
    #Name: LASTY_MILEAGE, dtype: float64
    if row['LASTY_MILEAGE']== -1:
        row_dict['LASTY_MILEAGE']='Unknown'
    elif row['LASTY_MILEAGE']<= 8000:
        row_dict['LASTY_MILEAGE']='short Last Mileage'
    elif row['LASTY_MILEAGE']> 8000 and row['LASTY_MILEAGE']<=14000:
        row_dict['LASTY_MILEAGE']='medium Last Mileage'
    elif row['LASTY_MILEAGE']> 14000 and row['LASTY_MILEAGE']<=20000:
        row_dict['LASTY_MILEAGE']='long Last Mileage'
    else:
        row_dict['LASTY_MILEAGE']='Very Long Last Mileage'
        
    # LASTY_CNT_ACTIVE_CGBY decribe how proactively client reserved for matainance services last years
    # numeric value = drop in times- text message notified times
    # need to decide if divide into ranges
    if row['LASTY_CNT_ACTIVE_CGBY']==-100:
        row_dict['LASTY_CNT_ACTIVE_CGBY']='Unknown'
    elif row['LASTY_CNT_ACTIVE_CGBY']> 0:
        row_dict['LASTY_CNT_ACTIVE_CGBY']='Active'
    else:
        row_dict['LASTY_CNT_ACTIVE_CGBY']='Not Active'
        
    #IF_TEST_DRIVE 0 means not sure if test drived, 1 and 2 means test_drived
    if row['IF_TEST_DRIVE']==1 or row['IF_TEST_DRIVE']==2:
        row_dict['IF_TEST_DRIVE']='Test Drived'
    else:
        row_dict['IF_TEST_DRIVE']='Unknown'
     
    
    
    # handling package grouped
    if row['package_grouped']=='低配':
        row_dict['package_grouped']='低配'
    if row['package_grouped']=='普配':
        row_dict['package_grouped']='普配'
    else:
        row_dict['package_grouped']='高配'
        
        
    #handling 去年是否进站
    if row['LASTY_CNT_JZ']>0:
        row_dict['LASTY_CNT_JZ']='去年进站过'
    else:
        row_dict['LASTY_CNT_JZ']='去年没进站'
    
    
    #IF_CMYCYJKQ 车门远程应急开启
    if row['IF_CMYCYJKQ']==1:
        row_dict['IF_CMYCYJKQ']='车门远程应急开启'
        
    
    #IF_MDDSZXZ 目的地设置协助
    if row['IF_MDDSZXZ']==1:
        row_dict['IF_MDDSZXZ']='目的地设置协助'
        
    #IF_CTWZTS 车停位置提示
    if row['IF_CTWZTS']==1:
        row_dict['IF_CTWZTS']='车停位置提示'
        
    #IF_JJJYXZ 紧急救援协助
    if row['IF_JJJYXZ']==1:
        row_dict['IF_JJJYXZ']='紧急救援协助'
        
    #IF_SSAXJC 实时按需检测
    if row['IF_SSAXJC']==1:
        row_dict['IF_SSAXJC']='实时按需检测'
        
    #IF_BDCLDW 被盗车辆定位
    if row['IF_BDCLDW']==1:
        row_dict['IF_BDCLDW']='被盗车辆定位'
    
    #IF_QCYKLH 全程音控导航
    if row['IF_QCYKLH']==1:
        row_dict['IF_QCYKLH']='全程音控导航'
        
    #IF_QYKMTDH 全程免提电话
    if row['IF_QYKMTDH']==1:
        row_dict['IF_QYKMTDH']='全程免提电话'
        
    #IF_LBJYXZ 路边救援协助
    if row['IF_LBJYXZ']==1:
        row_dict['IF_LBJYXZ']='路边救援协助'
        
    #IF_AQQNBKZZQZ 安全气囊拨开自助求助
    if row['IF_AQQNBKZZQZ']==1:
        row_dict['IF_AQQNBKZZQZ']='安全气囊拨开自助求助'
        
    #IF_CKJCBG 车况检测报告
    if row['IF_CKJCBG']==1:
        row_dict['IF_CKJCBG']='车况检测报告'
        
    #IF_PZZDQZ 碰撞自动求助
    if row['IF_PZZDQZ']==1:
        row_dict['IF_PZZDQZ']='碰撞自动求助'
    
    cadillac_dicts.append(row_dict)

# %%
# convert list of dicts to list of lists ready to passed to Aporiori package
result_list=[]
for dict in cadillac_dicts:
    row=[]
    for key,value in dict.items():
        if value!='Unknown':
            row.append(value)
    result_list.append(row)
result_list
# Out:
# [['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车门远程应急开启',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '目的地设置协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   'Test Drived',
#   '高配',
#   '去年进站过',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车门远程应急开启',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车门远程应急开启',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'AJX not installed',
#   'Female',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '4 Tier City',
#   '金卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '2 Tier City',
#   '金卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '路边救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '去年没进站',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '银卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'AJX not installed',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '3 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '高配',
#   '去年没进站'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '金卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   '高配',
#   '去年没进站',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Test Drived',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '银卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'School Age',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '高配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '5 Tier City',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '实时按需检测',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '银卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '去年没进站',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '金卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '5 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Test Drived',
#   '普配',
#   '去年没进站',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   'Unmarried',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 40s Older',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '银卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Extended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车门远程应急开启',
# ...
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Test Drived',
#   '高配',
#   '去年没进站',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '非会员',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   'Test Drived',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '去年没进站',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'AJX not installed',
#   'Female',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'AJX not installed',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '紧急救援协助'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '去年没进站',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '去年没进站',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   'Married',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '去年没进站',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '去年进站过',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '高配',
#   '去年没进站',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '去年进站过',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '高配',
#   '去年进站过',
#   '全程音控导航',
#   '车况检测报告']]

# %% [markdown]
# # Test Algorithm Effectiveness

# %%
# change target demographic group's Y value to 50000
test=cadillac
test.loc[(test['Gender']=='女')&(test['City']==1)&(test['Age']>30)&(test['Age']<40),'post_sale_y']=7001

# %%
# first step construct a list of dictionaries, each dictionary represent a row

# vin number skipped, MSRP waited till packages,if_org is already filtered,HOLD_GRAND all the same
# plan to store used one among the 12 services as a list, with key '12_services' 
# if_type_car all the same, insaic_money not mentioned in meeting,province and 
test_dicts = []
for index,row in test.iterrows():
    row_dict = {}
    
    # Temporarily set the post_sale_y threshold as 7000
    if row['post_sale_y']>7000:
        row_dict['post_sale_y']='High Customer Value'
    else:
        row_dict['post_sale_y']='Low Customer Value'
    
    # vehicles bought less than 18 months are considered new since first maintenance should be prior to that
    if row['first_buy_mon']>0 and row['first_buy_mon']<=12:
        row_dict['first_buy_mon']="1 year vehicle"
    # between a year and a half and 4 years is consider middle age 
    elif row['first_buy_mon']>12 and row['first_buy_mon']<=24:
        row_dict['first_buy_mon']="2 year vehicle"
        
    elif row['first_buy_mon']>24 and row['first_buy_mon']<=36:
        row_dict['first_buy_mon']="3 year vehicle"
    elif row['first_buy_mon']>36 and row['first_buy_mon']<=48:
        row_dict['first_buy_mon']="4 year vehicle"
    elif row['first_buy_mon']>48 and row['first_buy_mon']<=60:
        row_dict['first_buy_mon']="5 year vehicle"
    # more than 4 years is considered old since the max in this dataset is 58 and 75% percentile is 37
    elif row['first_buy_mon']>60:
        row_dict['first_buy_mon']="5 older vehicle"
    else:
        row_dict['first_buy_mon']='Unknown'
     
    
    
    # divide to 13 categories(13 keys), one is AJX not installed, the other 12 are 12 AJX serveices
    # if any one of these 13 applies to a vehicle, then it's dict contain the corresponding key value pair
    # where value is the chinses name of the key
    
    # 12 services can all coexist with the others, AJX not installed can only coexist with CKJCBG（车况检测报告）
    # since a few IF_AJX_cust==0 rows has IF_CKJCBG = 1
    services_12 = ['IF_CMYCYJKQ', 'IF_MDDSZXZ', 'IF_CTWZTS',
       'IF_JJJYXZ', 'IF_SSAXJC', 'IF_BDCLDW', 'IF_QCYKLH', 'IF_QYKMTDH',
       'IF_LBJYXZ', 'IF_AQQNBKZZQZ', 'IF_CKJCBG', 'IF_PZZDQZ']
    used=False
    for service in services_12:
        if row[service]==1:
            used=True
    if used == False:
        row_dict['IF_AJX_cust']='AJX not installed'
    
#     if row['IF_AJX_cust']==0:
#         if row['IF_CKJCBG']==0:
#             row_dict['IF_AJX_cust']='AJX not installed'
#         else:
#             row_dict['IF_AJX_cust']='AJX not installed but 车况检测报告'
    
    
    
    
    # handling gender, applied ffill to gender
    if row['Gender']=='男':
        row_dict['Gender'] = 'Male'
    elif row['Gender']=='女':
        row_dict['Gender'] = 'Female'
    else:
        row_dict['Gender'] = 'Unknown'
        
    
    #handling age, applied ffill to age
    # only less than 20% are older than 40
    if row['Age']<=24 and row['Age']>0:
        row_dict['Age'] = 'School Age'
    elif row['Age']>24 and row['Age']<30:
         row_dict['Age'] = 'Age 20s'
    elif row['Age']>=30 and row['Age']<40:
         row_dict['Age'] = 'Age 30s'
    elif row['Age']>=40:
         row_dict['Age'] = 'Age 40s Older'
    else:
         row_dict['Age'] = 'Unknown'
    
    
    #how to group provinces yet to be discussed, ask Daniel iff combine provinces
    d1=['浙江','上海','福建']
    d2=['江苏','安徽']
    d3=['广东','湖南','广西','江西','海南']
    d4=['四川','湖北','云南','贵州','重庆','新疆','甘肃','青海']
    d5=['山东','陕西','辽宁','吉林','黑龙江','内蒙古','山西','宁夏']
    d6=['北京','河南','河北','天津']
    if row['Province'] in d1:
        row_dict['Sales_district']='Sales_district1浙沪闽'
    elif row['Province'] in d2:
        row_dict['Sales_district']='Sales_district2江苏安徽'
    elif row['Province'] in d3:
        row_dict['Sales_district']='Sales_district3粤湘桂赣琼'
    elif row['Province'] in d4:
        row_dict['Sales_district']='Sales_district4云贵川鄂渝疆甘青'
    elif row['Province'] in d5:
        row_dict['Sales_district']='Sales_district5鲁陕辽吉黑蒙晋宁'
    elif row['Province'] in d6:
        row_dict['Sales_district']='Sales_district6河南河北京津'
    else:
         row_dict['Sales_district']='Unknown'
    
    
    # applied ffill to cities
    if row['City'] == 1:
        row_dict['City']= "1 Tier City"
    elif row['City']==2:
        row_dict['City'] = '2 Tier City'
    elif row['City']==3:
        row_dict['City'] = '3 Tier City'
    elif row['City']==4:
        row_dict['City'] = '4 Tier City'
    elif row['City']==0-1:
        row_dict['City'] = '5 Tier City'
    else:
        row_dict['City']='Unknown'
     
    
    # marriage -1 means other or unkown marital status, 1 means married, 2 means unmarried
    # more than 75% are unknown marital stuatus
    if row['Marriage']==1:
        row_dict['Marriage']= 'Married'
    elif row['Marriage']==2:
        row_dict['Marriage']= 'Unmarried'
    else:
        row_dict['Marriage']= 'Unknown'
      
    
    # null in level cadillac means not a member, already replaced null values with '非会员'
    if row['level_Cadillac']== '普卡':
        row_dict['level_Cadillac']='普卡'
    elif row['level_Cadillac']== '银卡':
        row_dict['level_Cadillac']='银卡'
    elif row['level_Cadillac']== '金卡':
        row_dict['level_Cadillac']='金卡'
    elif row['level_Cadillac']== '白金卡':
        row_dict['level_Cadillac']='白金卡'
    else:
        row_dict['level_Cadillac']='非会员'
    
    
    #insaic_cust 1 means client bought insaic insurance, 0 means bought from other sources
    if row['insaic_cust'] == 1:
        row_dict['insaic_cust']='Bought insaic'
    else:
        row_dict['insaic_cust']= 'Didnot buy insaic'
        
        
    # Warranty 0 means did not extend warranty, 1 means did extend warranty
    if row['Warranty']==1:
        row_dict['Warranty']='Extended Warranty'
    else:
        row_dict['Warranty']='Unextended Warranty'
    
    
    # IF_CAR_LOAN 1 means loaned from GM, 0 mean didnot loan from GM but not sure if loaned from others
    if row['IF_CAR_LOAN']==1:
        row_dict['IF_CAR_LOAN']='Loaned'
    else:
        row_dict['IF_CAR_LOAN']='Unloaned'
        
        
    
    #LASTY_MILEAGE
    # replaced null values with -1
    #count      636.000000
    #mean     16331.234543
    #std       9957.809315
    #min       1708.400613
    #25%       9696.742687
    #50%      14198.489512
    #75%      20111.688624
    #max      65905.044118
    #Name: LASTY_MILEAGE, dtype: float64
    if row['LASTY_MILEAGE']== -1:
        row_dict['LASTY_MILEAGE']='Unknown'
    elif row['LASTY_MILEAGE']<= 8000:
        row_dict['LASTY_MILEAGE']='short Last Mileage'
    elif row['LASTY_MILEAGE']> 8000 and row['LASTY_MILEAGE']<=14000:
        row_dict['LASTY_MILEAGE']='medium Last Mileage'
    elif row['LASTY_MILEAGE']> 14000 and row['LASTY_MILEAGE']<=20000:
        row_dict['LASTY_MILEAGE']='long Last Mileage'
    else:
        row_dict['LASTY_MILEAGE']='Very Long Last Mileage'
        
    # LASTY_CNT_ACTIVE_CGBY decribe how proactively client reserved for matainance services last years
    # numeric value = drop in times- text message notified times
    # need to decide if divide into ranges
    if row['LASTY_CNT_ACTIVE_CGBY']==-100:
        row_dict['LASTY_CNT_ACTIVE_CGBY']='Unknown'
    elif row['LASTY_CNT_ACTIVE_CGBY']> 0:
        row_dict['LASTY_CNT_ACTIVE_CGBY']='Active'
    else:
        row_dict['LASTY_CNT_ACTIVE_CGBY']='Not Active'
        
    #IF_TEST_DRIVE 0 means not sure if test drived, 1 and 2 means test_drived
    if row['IF_TEST_DRIVE']==1 or row['IF_TEST_DRIVE']==2:
        row_dict['IF_TEST_DRIVE']='Test Drived'
    else:
        row_dict['IF_TEST_DRIVE']='Unknown'
     
    
    
    # handling package grouped
    if row['package_grouped']=='低配':
        row_dict['package_grouped']='低配'
    if row['package_grouped']=='普配':
        row_dict['package_grouped']='普配'
    else:
        row_dict['package_grouped']='高配'
        
        
    #IF_CMYCYJKQ 车门远程应急开启
    if row['IF_CMYCYJKQ']==1:
        row_dict['IF_CMYCYJKQ']='车门远程应急开启'
        
    
    #IF_MDDSZXZ 目的地设置协助
    if row['IF_MDDSZXZ']==1:
        row_dict['IF_MDDSZXZ']='目的地设置协助'
        
    #IF_CTWZTS 车停位置提示
    if row['IF_CTWZTS']==1:
        row_dict['IF_CTWZTS']='车停位置提示'
        
    #IF_JJJYXZ 紧急救援协助
    if row['IF_JJJYXZ']==1:
        row_dict['IF_JJJYXZ']='紧急救援协助'
        
    #IF_SSAXJC 实时按需检测
    if row['IF_SSAXJC']==1:
        row_dict['IF_SSAXJC']='实时按需检测'
        
    #IF_BDCLDW 被盗车辆定位
    if row['IF_BDCLDW']==1:
        row_dict['IF_BDCLDW']='被盗车辆定位'
    
    #IF_QCYKLH 全程音控导航
    if row['IF_QCYKLH']==1:
        row_dict['IF_QCYKLH']='全程音控导航'
        
    #IF_QYKMTDH 全程免提电话
    if row['IF_QYKMTDH']==1:
        row_dict['IF_QYKMTDH']='全程免提电话'
        
    #IF_LBJYXZ 路边救援协助
    if row['IF_LBJYXZ']==1:
        row_dict['IF_LBJYXZ']='路边救援协助'
        
    #IF_AQQNBKZZQZ 安全气囊拨开自助求助
    if row['IF_AQQNBKZZQZ']==1:
        row_dict['IF_AQQNBKZZQZ']='安全气囊拨开自助求助'
        
    #IF_CKJCBG 车况检测报告
    if row['IF_CKJCBG']==1:
        row_dict['IF_CKJCBG']='车况检测报告'
        
    #IF_PZZDQZ 碰撞自动求助
    if row['IF_PZZDQZ']==1:
        row_dict['IF_PZZDQZ']='碰撞自动求助'
    
    test_dicts.append(row_dict)

# %%
test_result_list=[]
for dict in test_dicts:
    row=[]
    for key,value in dict.items():
        if value!='Unknown':
            row.append(value)
    test_result_list.append(row)
test_result_list
# Out:
# [['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '车门远程应急开启',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '目的地设置协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   'Test Drived',
#   '高配',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '车门远程应急开启',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '车门远程应急开启',
#   '目的地设置协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'AJX not installed',
#   'Female',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '4 Tier City',
#   '金卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '高配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '2 Tier City',
#   '金卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   'Test Drived',
#   '普配',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '路边救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '银卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   'Test Drived',
#   '普配',
#   '车门远程应急开启',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'AJX not installed',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '3 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '高配'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '金卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   '高配',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Test Drived',
#   '高配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '银卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '车门远程应急开启',
#   '全程音控导航'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'School Age',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '5 Tier City',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '实时按需检测',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '普配',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '银卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '普配',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '金卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '5 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Test Drived',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   'Unmarried',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车门远程应急开启',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 40s Older',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '银卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '非会员',
#   'Didnot buy insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Extended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '3 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '4 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Extended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '4 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '3 Tier City',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
# ...
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '车门远程应急开启',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '银卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Test Drived',
#   '高配',
#   '实时按需检测',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '高配',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '非会员',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   'Test Drived',
#   '高配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'AJX not installed',
#   'Female',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'AJX not installed',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Unmarried',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '3 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district2江苏安徽',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Female',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district6河南河北京津',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Not Active',
#   '普配',
#   '紧急救援协助',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告',
#   '碰撞自动求助'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '5 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '4 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district3粤湘桂赣琼',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '紧急救援协助'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '3 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '2 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '高配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district2江苏安徽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '1 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '4 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'medium Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Loaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district6河南河北京津',
#   '1 Tier City',
#   'Married',
#   '非会员',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '5 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '2 Tier City',
#   'Married',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'short Last Mileage',
#   'Active',
#   '普配',
#   '实时按需检测',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   '普配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['High Customer Value',
#   '3 year vehicle',
#   'Female',
#   'Age 30s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   'Test Drived',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Not Active',
#   '高配',
#   '全程音控导航',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '3 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district1浙沪闽',
#   '1 Tier City',
#   'Married',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'long Last Mileage',
#   'Active',
#   '高配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   'Sales_district3粤湘桂赣琼',
#   '3 Tier City',
#   '银卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Active',
#   '高配',
#   '车门远程应急开启',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Female',
#   'Age 20s',
#   'Sales_district4云贵川鄂渝疆甘青',
#   '5 Tier City',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'medium Last Mileage',
#   'Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'School Age',
#   'Sales_district1浙沪闽',
#   '3 Tier City',
#   'Unmarried',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 30s',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   '高配',
#   '车况检测报告'],
#  ['High Customer Value',
#   '2 year vehicle',
#   'Male',
#   'Age 20s',
#   'Sales_district5鲁陕辽吉黑蒙晋宁',
#   '1 Tier City',
#   '普卡',
#   'Didnot buy insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Not Active',
#   '普配',
#   '紧急救援协助',
#   '车况检测报告'],
#  ['Low Customer Value',
#   '1 year vehicle',
#   'Male',
#   'Age 40s Older',
#   'Sales_district2江苏安徽',
#   '2 Tier City',
#   'Married',
#   '普卡',
#   'Bought insaic',
#   'Unextended Warranty',
#   'Unloaned',
#   'Very Long Last Mileage',
#   'Not Active',
#   'Test Drived',
#   '高配',
#   '全程音控导航',
#   '车况检测报告']]

# %%
association_rules = apriori(test_result_list,min_support=0.045,min_confidence=0.2,min_lift=3.5,min_length=2)
for item in association_rules:
    pair = item[0]
    items = [x for x in pair]
    if items[1]=='Low Customer Value' or 'High Customer Value':
        print(item)
        # first index of the inner list
        # Contains base item and add item
        pair = item[0]
        print('pair is:')
        print(pair)
        items = [x for x in pair]
        print("Rule: " + items[0] + " -> " + items[1])

        #second index of the inner list
        print("Support: " + str(item[1]))

        #third index of the list located at 0th
        #of the third index of the inner list

        print("Confidence: " + str(item[2][0][2]))
        print("Lift: " + str(item[2][0][3]))
        print("=====================================")
# Out:
# RelationRecord(items=frozenset({'Married', '5 year vehicle', 'Age 30s'}), support=0.04628330995792426, ordered_statistics=[OrderedStatistic(items_base=frozenset({'5 year vehicle', 'Age 30s'}), items_add=frozenset({'Married'}), confidence=0.6470588235294118, lift=3.5763793889648885), OrderedStatistic(items_base=frozenset({'Married', 'Age 30s'}), items_add=frozenset({'5 year vehicle'}), confidence=0.515625, lift=3.953125)])
# pair is:
# frozenset({'Married', '5 year vehicle', 'Age 30s'})
# Rule: Married -> 5 year vehicle
# Support: 0.04628330995792426
# Confidence: 0.6470588235294118
# Lift: 3.5763793889648885
# =====================================
# RelationRecord(items=frozenset({'Didnot buy insaic', '5 year vehicle', 'Married'}), support=0.06732117812061711, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic'}), items_add=frozenset({'5 year vehicle'}), confidence=0.48484848484848486, lift=3.7171717171717176)])
# pair is:
# frozenset({'Didnot buy insaic', '5 year vehicle', 'Married'})
# Rule: Didnot buy insaic -> 5 year vehicle
# Support: 0.06732117812061711
# Confidence: 0.48484848484848486
# Lift: 3.7171717171717176
# =====================================
# RelationRecord(items=frozenset({'Married', '5 year vehicle', 'Unextended Warranty'}), support=0.07433380084151472, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.45689655172413796, lift=3.502873563218391)])
# pair is:
# frozenset({'Married', '5 year vehicle', 'Unextended Warranty'})
# Rule: Married -> 5 year vehicle
# Support: 0.07433380084151472
# Confidence: 0.45689655172413796
# Lift: 3.502873563218391
# =====================================
# RelationRecord(items=frozenset({'Married', '5 year vehicle', '普配'}), support=0.07573632538569425, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.48214285714285715, lift=3.6964285714285716)])
# pair is:
# frozenset({'Married', '5 year vehicle', '普配'})
# Rule: Married -> 5 year vehicle
# Support: 0.07573632538569425
# Confidence: 0.48214285714285715
# Lift: 3.6964285714285716
# =====================================
# RelationRecord(items=frozenset({'High Customer Value', '1 Tier City', 'Age 30s', 'Female'}), support=0.04908835904628331, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1 Tier City', 'Age 30s', 'Female'}), items_add=frozenset({'High Customer Value'}), confidence=0.8536585365853658, lift=4.256353402694866)])
# pair is:
# frozenset({'High Customer Value', '1 Tier City', 'Age 30s', 'Female'})
# Rule: High Customer Value -> 1 Tier City
# Support: 0.04908835904628331
# Confidence: 0.8536585365853658
# Lift: 4.256353402694866
# =====================================
# RelationRecord(items=frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', 'Low Customer Value'}), support=0.0546984572230014, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Didnot buy insaic', 'Married'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4936708860759494, lift=3.7848101265822787)])
# pair is:
# frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', 'Low Customer Value'})
# Rule: Didnot buy insaic -> 5 year vehicle
# Support: 0.0546984572230014
# Confidence: 0.4936708860759494
# Lift: 3.7848101265822787
# =====================================
# RelationRecord(items=frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', 'Unextended Warranty'}), support=0.06311360448807854, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4945054945054945, lift=3.7912087912087915)])
# pair is:
# frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', 'Unextended Warranty'})
# Rule: Didnot buy insaic -> 5 year vehicle
# Support: 0.06311360448807854
# Confidence: 0.4945054945054945
# Lift: 3.7912087912087915
# =====================================
# RelationRecord(items=frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', 'Unloaned'}), support=0.05049088359046283, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Didnot buy insaic', '5 year vehicle', 'Unloaned'}), items_add=frozenset({'Married'}), confidence=0.6666666666666666, lift=3.684754521963824), OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', 'Unloaned'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4864864864864865, lift=3.72972972972973)])
# pair is:
# frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', 'Unloaned'})
# Rule: Didnot buy insaic -> 5 year vehicle
# Support: 0.05049088359046283
# Confidence: 0.6666666666666666
# Lift: 3.684754521963824
# =====================================
# RelationRecord(items=frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', '普配'}), support=0.06451612903225806, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5411764705882353, lift=4.149019607843137)])
# pair is:
# frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', '普配'})
# Rule: Didnot buy insaic -> 5 year vehicle
# Support: 0.06451612903225806
# Confidence: 0.5411764705882353
# Lift: 4.149019607843137
# =====================================
# RelationRecord(items=frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', '车况检测报告'}), support=0.06451612903225806, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', '车况检测报告'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4791666666666667, lift=3.673611111111111)])
# pair is:
# frozenset({'Didnot buy insaic', '5 year vehicle', 'Married', '车况检测报告'})
# Rule: Didnot buy insaic -> 5 year vehicle
# Support: 0.06451612903225806
# Confidence: 0.4791666666666667
# Lift: 3.673611111111111
# =====================================
# RelationRecord(items=frozenset({'Low Customer Value', '5 year vehicle', 'Married', '普配'}), support=0.06030855539971949, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Married', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.48863636363636365, lift=3.7462121212121215)])
# pair is:
# frozenset({'Low Customer Value', '5 year vehicle', 'Married', '普配'})
# Rule: Low Customer Value -> 5 year vehicle
# Support: 0.06030855539971949
# Confidence: 0.48863636363636365
# Lift: 3.7462121212121215
# =====================================
# RelationRecord(items=frozenset({'Male', '5 year vehicle', 'Married', '普配'}), support=0.05049088359046283, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Male', 'Married', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5, lift=3.8333333333333335)])
# pair is:
# frozenset({'Male', '5 year vehicle', 'Married', '普配'})
# Rule: Male -> 5 year vehicle
# Support: 0.05049088359046283
# Confidence: 0.5
# Lift: 3.8333333333333335
# =====================================
# RelationRecord(items=frozenset({'Married', '5 year vehicle', '普配', 'Unextended Warranty'}), support=0.07152875175315568, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', '普配', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.51, lift=3.91)])
# pair is:
# frozenset({'Married', '5 year vehicle', '普配', 'Unextended Warranty'})
# Rule: Married -> 5 year vehicle
# Support: 0.07152875175315568
# Confidence: 0.51
# Lift: 3.91
# =====================================
# RelationRecord(items=frozenset({'Married', '5 year vehicle', '普配', 'Unloaned'}), support=0.0546984572230014, ordered_statistics=[OrderedStatistic(items_base=frozenset({'5 year vehicle', '普配', 'Unloaned'}), items_add=frozenset({'Married'}), confidence=0.639344262295082, lift=3.533739992375143), OrderedStatistic(items_base=frozenset({'Married', '普配', 'Unloaned'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4875, lift=3.7375)])
# pair is:
# frozenset({'Married', '5 year vehicle', '普配', 'Unloaned'})
# Rule: Married -> 5 year vehicle
# Support: 0.0546984572230014
# Confidence: 0.639344262295082
# Lift: 3.533739992375143
# =====================================
# RelationRecord(items=frozenset({'Married', '5 year vehicle', '车况检测报告', '普配'}), support=0.0729312762973352, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', '车况检测报告', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4727272727272727, lift=3.6242424242424245)])
# pair is:
# frozenset({'Married', '5 year vehicle', '车况检测报告', '普配'})
# Rule: Married -> 5 year vehicle
# Support: 0.0729312762973352
# Confidence: 0.4727272727272727
# Lift: 3.6242424242424245
# =====================================
# RelationRecord(items=frozenset({'Age 30s', 'Female', 'Unextended Warranty', 'High Customer Value', '1 Tier City'}), support=0.04628330995792426, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Unextended Warranty', '1 Tier City', 'Age 30s', 'Female'}), items_add=frozenset({'High Customer Value'}), confidence=0.868421052631579, lift=4.32995951417004)])
# pair is:
# frozenset({'Age 30s', 'Female', 'Unextended Warranty', 'High Customer Value', '1 Tier City'})
# Rule: Age 30s -> Female
# Support: 0.04628330995792426
# Confidence: 0.868421052631579
# Lift: 4.32995951417004
# =====================================
# RelationRecord(items=frozenset({'Age 30s', 'Female', 'High Customer Value', '车况检测报告', '1 Tier City'}), support=0.04908835904628331, ordered_statistics=[OrderedStatistic(items_base=frozenset({'车况检测报告', '1 Tier City', 'Age 30s', 'Female'}), items_add=frozenset({'High Customer Value'}), confidence=0.8536585365853658, lift=4.256353402694866)])
# pair is:
# frozenset({'Age 30s', 'Female', 'High Customer Value', '车况检测报告', '1 Tier City'})
# Rule: Age 30s -> Female
# Support: 0.04908835904628331
# Confidence: 0.8536585365853658
# Lift: 4.256353402694866
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value'}), support=0.05049088359046283, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Didnot buy insaic', 'Married', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4931506849315068, lift=3.780821917808219)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.05049088359046283
# Confidence: 0.4931506849315068
# Lift: 3.780821917808219
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', 'Low Customer Value', '普配'}), support=0.05329593267882188, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Didnot buy insaic', 'Married', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5588235294117647, lift=4.284313725490196)])
# pair is:
# frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', 'Low Customer Value', '普配'})
# Rule: 5 year vehicle -> Married
# Support: 0.05329593267882188
# Confidence: 0.5588235294117647
# Lift: 4.284313725490196
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告'}), support=0.051893408134642355, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Didnot buy insaic', 'Married', '车况检测报告'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4868421052631579, lift=3.7324561403508776)])
# pair is:
# frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告'})
# Rule: 5 year vehicle -> Married
# Support: 0.051893408134642355
# Confidence: 0.4868421052631579
# Lift: 3.7324561403508776
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Unloaned'}), support=0.04628330995792426, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Didnot buy insaic', '5 year vehicle', 'Unloaned', 'Unextended Warranty'}), items_add=frozenset({'Married'}), confidence=0.66, lift=3.6479069767441863), OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', 'Unloaned', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4852941176470588, lift=3.7205882352941178)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Unloaned'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.04628330995792426
# Confidence: 0.66
# Lift: 3.6479069767441863
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', '普配'}), support=0.06030855539971949, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', '普配', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5512820512820513, lift=4.226495726495727)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.06030855539971949
# Confidence: 0.5512820512820513
# Lift: 4.226495726495727
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', '车况检测报告'}), support=0.06030855539971949, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', '车况检测报告', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.48863636363636365, lift=3.7462121212121215)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', '车况检测报告'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.06030855539971949
# Confidence: 0.48863636363636365
# Lift: 3.7462121212121215
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', '普配', 'Unloaned'}), support=0.047685834502103785, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Didnot buy insaic', '5 year vehicle', '普配', 'Unloaned'}), items_add=frozenset({'Married'}), confidence=0.6666666666666666, lift=3.684754521963824), OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', '普配', 'Unloaned'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5573770491803278, lift=4.273224043715847)])
# pair is:
# frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', '普配', 'Unloaned'})
# Rule: 5 year vehicle -> Married
# Support: 0.047685834502103785
# Confidence: 0.6666666666666666
# Lift: 3.684754521963824
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', '车况检测报告', 'Unloaned'}), support=0.047685834502103785, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Didnot buy insaic', '5 year vehicle', '车况检测报告', 'Unloaned'}), items_add=frozenset({'Married'}), confidence=0.6538461538461539, lift=3.613893858079905), OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', '车况检测报告', 'Unloaned'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4788732394366197, lift=3.6713615023474175)])
# pair is:
# frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', '车况检测报告', 'Unloaned'})
# Rule: 5 year vehicle -> Married
# Support: 0.047685834502103785
# Confidence: 0.6538461538461539
# Lift: 3.613893858079905
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', '车况检测报告', '普配'}), support=0.061711079943899017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', 'Didnot buy insaic', '车况检测报告', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5301204819277109, lift=4.064257028112451)])
# pair is:
# frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', '车况检测报告', '普配'})
# Rule: 5 year vehicle -> Married
# Support: 0.061711079943899017
# Confidence: 0.5301204819277109
# Lift: 4.064257028112451
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Low Customer Value', 'Married', '普配'}), support=0.056100981767180924, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Married', '普配', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5063291139240507, lift=3.8818565400843887)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Low Customer Value', 'Married', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.056100981767180924
# Confidence: 0.5063291139240507
# Lift: 3.8818565400843887
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Low Customer Value', 'Married', '车况检测报告', '普配'}), support=0.05750350631136045, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Married', '普配', '车况检测报告'}), items_add=frozenset({'5 year vehicle'}), confidence=0.47674418604651164, lift=3.6550387596899228)])
# pair is:
# frozenset({'5 year vehicle', 'Low Customer Value', 'Married', '车况检测报告', '普配'})
# Rule: 5 year vehicle -> Low Customer Value
# Support: 0.05750350631136045
# Confidence: 0.47674418604651164
# Lift: 3.6550387596899228
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Male', '普配'}), support=0.04628330995792426, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Male', 'Married', '普配', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5, lift=3.8333333333333335)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Male', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.04628330995792426
# Confidence: 0.5
# Lift: 3.8333333333333335
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', '车况检测报告', 'Male', '普配'}), support=0.04908835904628331, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Male', 'Married', '普配', '车况检测报告'}), items_add=frozenset({'5 year vehicle'}), confidence=0.49295774647887325, lift=3.779342723004695)])
# pair is:
# frozenset({'5 year vehicle', 'Married', '车况检测报告', 'Male', '普配'})
# Rule: 5 year vehicle -> Married
# Support: 0.04908835904628331
# Confidence: 0.49295774647887325
# Lift: 3.779342723004695
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', '普配', 'Unloaned'}), support=0.05049088359046283, ordered_statistics=[OrderedStatistic(items_base=frozenset({'5 year vehicle', '普配', 'Unloaned', 'Unextended Warranty'}), items_add=frozenset({'Married'}), confidence=0.6428571428571429, lift=3.5531561461794023), OrderedStatistic(items_base=frozenset({'Married', '普配', 'Unloaned', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5070422535211268, lift=3.887323943661972)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', '普配', 'Unloaned'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.05049088359046283
# Confidence: 0.6428571428571429
# Lift: 3.5531561461794023
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', '车况检测报告', '普配'}), support=0.06872370266479663, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', '车况检测报告', '普配', 'Unextended Warranty'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5, lift=3.8333333333333335)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', '车况检测报告', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.06872370266479663
# Confidence: 0.5
# Lift: 3.8333333333333335
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', '车况检测报告', '普配', 'Unloaned'}), support=0.051893408134642355, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Married', '车况检测报告', '普配', 'Unloaned'}), items_add=frozenset({'5 year vehicle'}), confidence=0.47435897435897434, lift=3.6367521367521367)])
# pair is:
# frozenset({'5 year vehicle', 'Married', '车况检测报告', '普配', 'Unloaned'})
# Rule: 5 year vehicle -> Married
# Support: 0.051893408134642355
# Confidence: 0.47435897435897434
# Lift: 3.6367521367521367
# =====================================
# RelationRecord(items=frozenset({'Age 30s', 'Female', 'Unextended Warranty', 'High Customer Value', '车况检测报告', '1 Tier City'}), support=0.04628330995792426, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Age 30s', 'Female', 'Unextended Warranty', '车况检测报告', '1 Tier City'}), items_add=frozenset({'High Customer Value'}), confidence=0.868421052631579, lift=4.32995951417004)])
# pair is:
# frozenset({'Age 30s', 'Female', 'Unextended Warranty', 'High Customer Value', '车况检测报告', '1 Tier City'})
# Rule: Age 30s -> Female
# Support: 0.04628330995792426
# Confidence: 0.868421052631579
# Lift: 4.32995951417004
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value', '普配'}), support=0.04908835904628331, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Unextended Warranty', 'Low Customer Value', 'Didnot buy insaic', 'Married', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5645161290322581, lift=4.327956989247312)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.04908835904628331
# Confidence: 0.5645161290322581
# Lift: 4.327956989247312
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告'}), support=0.047685834502103785, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Unextended Warranty', 'Low Customer Value', 'Didnot buy insaic', 'Married', '车况检测报告'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4857142857142857, lift=3.723809523809524)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.047685834502103785
# Confidence: 0.4857142857142857
# Lift: 3.723809523809524
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告', '普配'}), support=0.05049088359046283, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Low Customer Value', 'Didnot buy insaic', 'Married', '车况检测报告', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5454545454545454, lift=4.181818181818182)])
# pair is:
# frozenset({'5 year vehicle', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告', '普配'})
# Rule: 5 year vehicle -> Married
# Support: 0.05049088359046283
# Confidence: 0.5454545454545454
# Lift: 4.181818181818182
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', '车况检测报告', '普配'}), support=0.05750350631136045, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Unextended Warranty', 'Married', 'Didnot buy insaic', '车况检测报告', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.5394736842105263, lift=4.135964912280702)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', '车况检测报告', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.05750350631136045
# Confidence: 0.5394736842105263
# Lift: 4.135964912280702
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Low Customer Value', 'Married', '车况检测报告', '普配'}), support=0.05329593267882188, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Unextended Warranty', 'Low Customer Value', 'Married', '车况检测报告', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4935064935064935, lift=3.7835497835497836)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Low Customer Value', 'Married', '车况检测报告', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.05329593267882188
# Confidence: 0.4935064935064935
# Lift: 3.7835497835497836
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', '车况检测报告', '普配', 'Unloaned'}), support=0.047685834502103785, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Unextended Warranty', 'Married', '车况检测报告', '普配', 'Unloaned'}), items_add=frozenset({'5 year vehicle'}), confidence=0.4927536231884058, lift=3.777777777777778)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', '车况检测报告', '普配', 'Unloaned'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.047685834502103785
# Confidence: 0.4927536231884058
# Lift: 3.777777777777778
# =====================================
# RelationRecord(items=frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告', '普配'}), support=0.04628330995792426, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Unextended Warranty', 'Low Customer Value', 'Didnot buy insaic', 'Married', '车况检测报告', '普配'}), items_add=frozenset({'5 year vehicle'}), confidence=0.55, lift=4.216666666666667)])
# pair is:
# frozenset({'5 year vehicle', 'Unextended Warranty', 'Married', 'Didnot buy insaic', 'Low Customer Value', '车况检测报告', '普配'})
# Rule: 5 year vehicle -> Unextended Warranty
# Support: 0.04628330995792426
# Confidence: 0.55
# Lift: 4.216666666666667
# =====================================
